# %% [markdown]
# # WeatherPy
# __________________________________________________________________

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy as np
import requests
import time
from api_keys import api_key
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls

# %%
# url for API
url = "http://api.openweathermap.org/data/2.5/weather?"
params = {
    "appid":api_key,
    "units":"imperial"
}
# city container list
city_data = []

# %%
#logger
print("Beginning Data Retrieval ")
print("_______________________________")

# counter list
set_counter = 1
record_counter = 1

for city in cities:
    params["q"] = city
    response = requests.get(url, params=params)
    # when looping through, skip if city isn't found
    if response.ok == False:
        print(" City not found.   Skipping...")
        pass
    else:    
        response_json = response.json()
        weather_dict = {
            "City":response_json["name"], 
            "Country":response_json["sys"]["country"],
            "Date":response_json["dt"],
            "Latitude":response_json["coord"]["lat"],
            "Longitude":response_json["coord"]["lon"],
            "Cloudiness":response_json["clouds"]["all"],
            "Humidity":response_json["main"]["humidity"],
            "Max Temp":response_json["main"]["temp_max"],
            "Wind Speed":response_json["wind"]["speed"]
        }
        city_data.append(weather_dict)
        print(f"Processing Record {record_counter} of Set {set_counter} | {weather_dict['City']}")
        record_counter += 1
        
              
              
              
        #utilize the counter
        if record_counter % 50 == 0:
            set_counter += 1
            record_counter = 1
print("_______________________________")
print("Data Retrieval Complete")
print("_______________________________")
# Out:
# Beginning Data Retrieval
# _______________________________
#  City not found.   Skipping...
# Processing Record 1 of Set 1 | Hofn
# Processing Record 2 of Set 1 | Hermanus
# Processing Record 3 of Set 1 | Mayya
# Processing Record 4 of Set 1 | Port Alfred
# Processing Record 5 of Set 1 | Punta Arenas
# Processing Record 6 of Set 1 | Busselton
# Processing Record 7 of Set 1 | Chokurdakh
# Processing Record 8 of Set 1 | Ploskoye
# Processing Record 9 of Set 1 | Antsohihy
# Processing Record 10 of Set 1 | Waipawa
# Processing Record 11 of Set 1 | Saint-Joseph
# Processing Record 12 of Set 1 | Thompson
# Processing Record 13 of Set 1 | Ushuaia
# Processing Record 14 of Set 1 | Khatanga
# Processing Record 15 of Set 1 | Atuona
# Processing Record 16 of Set 1 | Bluff
# Processing Record 17 of Set 1 | Flagstaff
# Processing Record 18 of Set 1 | Luderitz
# Processing Record 19 of Set 1 | Albany
# Processing Record 20 of Set 1 | Charleston
# Processing Record 21 of Set 1 | Bathsheba
#  City not found.   Skipping...
# Processing Record 22 of Set 1 | New Norfolk
# Processing Record 23 of Set 1 | Gejiu
#  City not found.   Skipping...
# Processing Record 24 of Set 1 | Laas
# Processing Record 25 of Set 1 | Talcahuano
# Processing Record 26 of Set 1 | Saint-Philippe
# Processing Record 27 of Set 1 | La Palma
# Processing Record 28 of Set 1 | Mayo
# Processing Record 29 of Set 1 | Lorengau
# Processing Record 30 of Set 1 | Rikitea
# Processing Record 31 of Set 1 | Saldanha
# Processing Record 32 of Set 1 | Qaanaaq
# Processing Record 33 of Set 1 | Pisco
# Processing Record 34 of Set 1 | Taitung City
#  City not found.   Skipping...
# Processing Record 35 of Set 1 | Gebre Guracha
# Processing Record 36 of Set 1 | Nikolskoye
# Processing Record 37 of Set 1 | Colares
# Processing Record 38 of Set 1 | Ahipara
# Processing Record 39 of Set 1 | Shenjiamen
# Processing Record 29 of Set 4 | Pacific Grove
# Processing Record 30 of Set 4 | Ostrovnoy
# Processing Record 31 of Set 4 | Lyskovo
#  City not found.   Skipping...
# Processing Record 32 of Set 4 | Taraz
# Processing Record 33 of Set 4 | Jumla
# Processing Record 34 of Set 4 | Saint Anthony
# Processing Record 35 of Set 4 | Nema
# Processing Record 36 of Set 4 | Porangatu
# Processing Record 37 of Set 4 | Umm Lajj
# Processing Record 38 of Set 4 | Bredasdorp
# Processing Record 39 of Set 4 | Rincon
# Processing Record 40 of Set 4 | Borogontsy
# Processing Record 41 of Set 4 | Kyzyl-Suu
# Processing Record 42 of Set 4 | Sao Gabriel da Cachoeira
# Processing Record 43 of Set 4 | Coahuayana Viejo
# Processing Record 44 of Set 4 | Ghanzi
# Processing Record 45 of Set 4 | Mar del Plata
# Processing Record 46 of Set 4 | Maceio
# Processing Record 47 of Set 4 | Sitka
# Processing Record 48 of Set 4 | Novoanninskiy
# Processing Record 49 of Set 4 | Rawson
# Processing Record 1 of Set 5 | Saint George
#  City not found.   Skipping...
# Processing Record 2 of Set 5 | Karratha
# Processing Record 3 of Set 5 | North Bend
# Processing Record 4 of Set 5 | Padang
# Processing Record 5 of Set 5 | Avera
# Processing Record 6 of Set 5 | Banda Aceh
# Processing Record 7 of Set 5 | Kirakira
# Processing Record 8 of Set 5 | Ludhiana
# Processing Record 9 of Set 5 | Cabinda
# Processing Record 10 of Set 5 | Teguise
# Processing Record 11 of Set 5 | George Town
# Processing Record 12 of Set 5 | Mariental
# Processing Record 13 of Set 5 | Puerto Ayora
# Processing Record 14 of Set 5 | Preobrazheniye
# Processing Record 15 of Set 5 | Eureka
# Processing Record 16 of Set 5 | Vrede
# Processing Record 17 of Set 5 | Samarai
# Processing Record 18 of Set 5 | Henties Bay
# Processing Record 19 of Set 5 | Santa Isabel do Rio Negro
# Processing Record 20 of Set 5 | Port Elizabeth
# Processing Record 21 of Set 5 | Richards Bay
# Processing Record 22 of Set 5 | Abu Zabad
# Processing Record 23 of Set 5 | Honningsvag
# Processing Record 24 of Set 5 | Katangli
#  City not found.   Skipping...
# Processing Record 25 of Set 5 | Avarua
# Processing Record 26 of Set 5 | Fecamp
# Processing Record 27 of Set 5 | Verkhnevilyuysk
# Processing Record 28 of Set 5 | Tigil
# Processing Record 29 of Set 5 | Marystown
# Processing Record 30 of Set 5 | San Cristobal
# Processing Record 31 of Set 5 | Castro
# Processing Record 32 of Set 5 | Oussouye
# Processing Record 33 of Set 5 | Vila Franca do Campo
# Processing Record 34 of Set 5 | Ryotsu
# Processing Record 35 of Set 5 | Nemuro
# Processing Record 36 of Set 5 | Tocopilla
# Processing Record 37 of Set 5 | Tondano
#  City not found.   Skipping...
# Processing Record 38 of Set 5 | Tautira
# Processing Record 39 of Set 5 | Adre
# Processing Record 40 of Set 5 | Hammerfest
#  City not found.   Skipping...
# Processing Record 41 of Set 5 | Algodones
#  City not found.   Skipping...
# Processing Record 42 of Set 5 | La Ronge
#  City not found.   Skipping...
# Processing Record 43 of Set 5 | Tiznit
# Processing Record 44 of Set 5 | Avallon
# Processing Record 45 of Set 5 | Culpeper
# Processing Record 46 of Set 5 | Codrington
# Processing Record 47 of Set 5 | Beloha
# Processing Record 48 of Set 5 | Garbolovo
# Processing Record 49 of Set 5 | Meulaboh
# Processing Record 1 of Set 6 | Bansi
# Processing Record 2 of Set 6 | Bilibino
# Processing Record 3 of Set 6 | Olot
# Processing Record 4 of Set 6 | Whitianga
#  City not found.   Skipping...
# Processing Record 5 of Set 6 | Saskylakh
# Processing Record 6 of Set 6 | Asau
# Processing Record 7 of Set 6 | Auki
# Processing Record 8 of Set 6 | Udarnyy
# Processing Record 9 of Set 6 | North Platte
# Processing Record 10 of Set 6 | Pujili
# Processing Record 11 of Set 6 | Mahebourg
# Processing Record 12 of Set 6 | Newcastle
#  City not found.   Skipping...
# Processing Record 13 of Set 6 | Leshukonskoye
# Processing Record 14 of Set 6 | Banamba
# Processing Record 15 of Set 6 | Norman Wells
# Processing Record 16 of Set 6 | Awjilah
# Processing Record 17 of Set 6 | Barrow
# Processing Record 18 of Set 6 | Gbarnga
#  City not found.   Skipping...
# Processing Record 19 of Set 6 | Haines Junction
# Processing Record 20 of Set 6 | Nyurba
# Processing Record 21 of Set 6 | Linxia
# Processing Record 22 of Set 6 | Aracaju
# Processing Record 23 of Set 6 | Laguna
# Processing Record 24 of Set 6 | Altoona
# Processing Record 25 of Set 6 | Nichinan
# Processing Record 26 of Set 6 | Pevek
# Processing Record 27 of Set 6 | Zyryanka
# Processing Record 28 of Set 6 | Sydney
# Processing Record 29 of Set 6 | Itarema
#  City not found.   Skipping...
# Processing Record 30 of Set 6 | Upernavik
# Processing Record 31 of Set 6 | Kokopo
# Processing Record 32 of Set 6 | Ust-Maya
# Processing Record 33 of Set 6 | Comodoro Rivadavia
# Processing Record 34 of Set 6 | Inhambane
# Processing Record 35 of Set 6 | Hangu
# Processing Record 36 of Set 6 | Orlik
# Processing Record 37 of Set 6 | Sao Jose da Coroa Grande
# Processing Record 38 of Set 6 | Batsfjord
#  City not found.   Skipping...
# Processing Record 39 of Set 6 | Cruzeiro do Sul
# Processing Record 40 of Set 6 | Fare
# Processing Record 41 of Set 6 | Alamosa
# Processing Record 42 of Set 6 | East London
# Processing Record 43 of Set 6 | Moussoro
# Processing Record 44 of Set 6 | Kendari
# Processing Record 45 of Set 6 | Mozhaysk
# Processing Record 46 of Set 6 | Saint-Augustin
# Processing Record 47 of Set 6 | Messina
#  City not found.   Skipping...
# Processing Record 48 of Set 6 | Cabo San Lucas
# Processing Record 49 of Set 6 | Punta Alta
# Processing Record 1 of Set 7 | Hilo
# Processing Record 2 of Set 7 | Sao Borja
# Processing Record 3 of Set 7 | Pochtovoye
# Processing Record 4 of Set 7 | Outlook
# Processing Record 5 of Set 7 | Koumac
# Processing Record 6 of Set 7 | Surgut
# Processing Record 7 of Set 7 | Astana
# Processing Record 8 of Set 7 | Menomonie
# Processing Record 9 of Set 7 | Hamilton
#  City not found.   Skipping...
# Processing Record 10 of Set 7 | Te Anau
# Processing Record 11 of Set 7 | Sur
# Processing Record 12 of Set 7 | Klaeng
# Processing Record 13 of Set 7 | Segezha
# Processing Record 14 of Set 7 | Herat
#  City not found.   Skipping...
# Processing Record 2 of Set 10 | Nueve de Julio
# Processing Record 3 of Set 10 | Torbay
# Processing Record 4 of Set 10 | San Miguelito
# Processing Record 5 of Set 10 | Vila Velha
# Processing Record 6 of Set 10 | Petropavlovsk-Kamchatsky
# Processing Record 7 of Set 10 | Woodstock
# Processing Record 8 of Set 10 | Deniliquin
# Processing Record 9 of Set 10 | Yar-Sale
# Processing Record 10 of Set 10 | Mount Isa
# Processing Record 11 of Set 10 | Anori
#  City not found.   Skipping...
# Processing Record 12 of Set 10 | Geraldton
# Processing Record 13 of Set 10 | Tortoli
#  City not found.   Skipping...
# Processing Record 14 of Set 10 | Singaraja
# Processing Record 15 of Set 10 | Najran
# Processing Record 16 of Set 10 | Weinan
# Processing Record 17 of Set 10 | Sohag
# Processing Record 18 of Set 10 | Port Augusta
#  City not found.   Skipping...
# Processing Record 19 of Set 10 | Nadym
# Processing Record 20 of Set 10 | Beringovskiy
# Processing Record 21 of Set 10 | Santa Flavia
# Processing Record 22 of Set 10 | Verkhniy Ufaley
# Processing Record 23 of Set 10 | Tura
# Processing Record 24 of Set 10 | Lowestoft
# Processing Record 25 of Set 10 | Ossora
# Processing Record 26 of Set 10 | Ponta Delgada
# Processing Record 27 of Set 10 | Belmonte
# Processing Record 28 of Set 10 | Mildura
# Processing Record 29 of Set 10 | Abapo
# Processing Record 30 of Set 10 | Ocos
# Processing Record 31 of Set 10 | Aksu
# Processing Record 32 of Set 10 | Baharly
# Processing Record 33 of Set 10 | Departamento de Maldonado
# Processing Record 34 of Set 10 | Roald
# Processing Record 35 of Set 10 | Jinxiang
# Processing Record 36 of Set 10 | Lac du Bonnet
# Processing Record 37 of Set 10 | Viedma
# Processing Record 38 of Set 10 | Kawalu
# Processing Record 39 of Set 10 | Launceston
#  City not found.   Skipping...
# Processing Record 40 of Set 10 | Quatre Cocos
# Processing Record 41 of Set 10 | Sol'-Iletsk
# Processing Record 42 of Set 10 | Moose Factory
# Processing Record 43 of Set 10 | Brigantine
# Processing Record 44 of Set 10 | Puerto Escondido
# Processing Record 45 of Set 10 | Esperance
# Processing Record 46 of Set 10 | Gushikawa
# Processing Record 47 of Set 10 | Angoche
# Processing Record 48 of Set 10 | Bukachacha
# Processing Record 49 of Set 10 | Uwajima
# Processing Record 1 of Set 11 | Nanakuli
# Processing Record 2 of Set 11 | San Bartolome de Tirajana
#  City not found.   Skipping...
# Processing Record 3 of Set 11 | Ushumun
# Processing Record 4 of Set 11 | Kiryat Gat
# Processing Record 5 of Set 11 | Ust-Nera
# Processing Record 6 of Set 11 | Rypefjord
# Processing Record 7 of Set 11 | Sao Miguel do Araguaia
# Processing Record 8 of Set 11 | Uribia
# Processing Record 9 of Set 11 | Dicabisagan
# Processing Record 10 of Set 11 | Timra
# Processing Record 11 of Set 11 | Topolobampo
# Processing Record 12 of Set 11 | Hambantota
# Processing Record 13 of Set 11 | Bam
# Processing Record 14 of Set 11 | Kungurtug
# Processing Record 15 of Set 11 | Okhotsk
# Processing Record 16 of Set 11 | Whitecourt
#  City not found.   Skipping...
# Processing Record 17 of Set 11 | Senneterre
# Processing Record 18 of Set 11 | Poum
# Processing Record 19 of Set 11 | Soyo
# Processing Record 20 of Set 11 | Touros
# Processing Record 21 of Set 11 | Zhezkazgan
# Processing Record 22 of Set 11 | Haimen
# Processing Record 23 of Set 11 | Port Hardy
# Processing Record 24 of Set 11 | Egvekinot
# Processing Record 25 of Set 11 | Ukiah
# Processing Record 26 of Set 11 | Jangaon
# Processing Record 27 of Set 11 | Biscarrosse
# Processing Record 28 of Set 11 | Batagay-Alyta
# Processing Record 29 of Set 11 | Say
# Processing Record 30 of Set 11 | Victor Harbor
# Processing Record 31 of Set 11 | Barra de Tecoanapa
# Processing Record 32 of Set 11 | Oranjestad
# Processing Record 33 of Set 11 | Saryozek
# Processing Record 34 of Set 11 | Brazzaville
# Processing Record 35 of Set 11 | Terra Santa
# Processing Record 36 of Set 11 | Deputatsky
# Processing Record 37 of Set 11 | Cape Coast
# Processing Record 38 of Set 11 | Kruisfontein
# Processing Record 39 of Set 11 | Makakilo City
# Processing Record 40 of Set 11 | Kloulklubed
# Processing Record 41 of Set 11 | Zaysan
# Processing Record 42 of Set 11 | Salina
# Processing Record 43 of Set 11 | Zhangjiakou
# Processing Record 44 of Set 11 | Gornyy
# Processing Record 45 of Set 11 | Sinnai
# Processing Record 46 of Set 11 | Batemans Bay
# Processing Record 47 of Set 11 | Chara
# Processing Record 48 of Set 11 | Tommot
# Processing Record 49 of Set 11 | Heishan
# Processing Record 1 of Set 12 | Pyu
# Processing Record 2 of Set 12 | Saint-Pierre
# Processing Record 3 of Set 12 | Mexico
# Processing Record 4 of Set 12 | College
# Processing Record 5 of Set 12 | Rodolfo Sanchez Taboada
# Processing Record 6 of Set 12 | Palmer
# Processing Record 7 of Set 12 | Trinidad
# Processing Record 8 of Set 12 | Ubari
# Processing Record 9 of Set 12 | Corrente
# Processing Record 10 of Set 12 | Clarksdale
#  City not found.   Skipping...
# Processing Record 11 of Set 12 | Yabrud
# Processing Record 12 of Set 12 | Iskateley
# Processing Record 13 of Set 12 | Novo Aripuana
# Processing Record 14 of Set 12 | Pangody
# Processing Record 15 of Set 12 | Tonstad
# _______________________________
# Data Retrieval Complete
# _______________________________

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
# pandas dataframe
city_pd = pd.DataFrame(city_data)

lat = city_pd["Latitude"]
maxtemp = city_pd["Max Temp"]
hum = city_pd["Humidity"]
winds = city_pd["Wind Speed"]
clouds = city_pd["Cloudiness"]

# %%
# export
city_pd.to_csv(output_data_file, index_label="City_ID")

city_pd.head()
# Out:
#            City  Cloudiness Country        Date  Humidity  Latitude  \
# 0          Hofn          86      IS  1579151560        89     64.25
# 1      Hermanus           8      ZA  1579151560        82    -34.42
# 2         Mayya          75      RU  1579151560        74     61.73
# 3   Port Alfred           2      ZA  1579151560        94    -33.59
# 4  Punta Arenas          20      CL  1579151561        60    -53.15
#
#    Longitude  Max Temp  Wind Speed
# 0     -15.21     39.45       13.35
# 1      19.23     75.99        7.00
# 2     130.28    -23.80        2.24
# 3      26.89     75.00        5.06
# 4     -70.92     42.80       13.87

# %% [markdown]
# ### Plotting the Data

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
